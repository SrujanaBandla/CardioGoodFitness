# %% [markdown]
# # Import the necessary libraries

# %%
#Import the necessary packages - pandas, numpy, seaborn, matplotlib.pyplot
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore') # To supress warnings

# %% [markdown]
# ## Load the dataset

# %%
# Reading the dataset by using read_csv from pandas package
cardiofitness_data = pd.read_csv("/Users/srujana/Downloads/CardioGoodFitness.csv")

# %% [markdown]
# ## Verify if the data is loaded properly

# %%
#View the first 5 rows of the dataset
cardiofitness_data .head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47

# %% [markdown]
# ## View the shape of the dataset

# %%
#View the shape of the dataset(number of rows and columns)
cardiofitness_data .shape
# Out:
# (180, 9)

# %% [markdown]
# ### Observation:
# There are 180 rows and 9 columns in the Cardio Fitness dataset

# %% [markdown]
# ## Verify the datatypes of the columns

# %%
#Check the data types of the columns in the dataset.
cardiofitness_data.dtypes
# Out:
# Product          object
# Age               int64
# Gender           object
# Education         int64
# MaritalStatus    object
# Usage             int64
# Fitness           int64
# Income            int64
# Miles             int64
# dtype: object

# %% [markdown]
# ## Count the datatypes

# %%
#count the number of variables in each datatype
cardiofitness_data.dtypes.value_counts()
# Out:
# int64     6
# object    3
# dtype: int64

# %% [markdown]
# ## Check the columns

# %%
#View the column names
cardiofitness_data.columns
# Out:
# Index(['Product', 'Age', 'Gender', 'Education', 'MaritalStatus', 'Usage',
#        'Fitness', 'Income', 'Miles'],
#       dtype='object')

# %% [markdown]
# ## Check the data set information

# %%
cardiofitness_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %% [markdown]
# ### Observations:
# All the columns are either of type object or int64.
#
# 1. Age,Education,Usage,Fitness,Income and Miles columns are of integer data type.
# 2. Product, Gender and MaritalStatus columns should be categorical.

# %% [markdown]
# ## Let's convert the categorical columns from object datatype to category

# %%
# Correcting the datatypes of the columns
cardiofitness_data['Product'] = cardiofitness_data.Product.astype('category')
cardiofitness_data['Gender'] = cardiofitness_data.Gender.astype('category')
cardiofitness_data['MaritalStatus'] = cardiofitness_data.MaritalStatus.astype('category')

# %% [markdown]
# ### Lets verify if the datatypes issue is fixed

# %%
cardiofitness_data.dtypes
# Out:
# Product          category
# Age                 int64
# Gender           category
# Education           int64
# MaritalStatus    category
# Usage               int64
# Fitness             int64
# Income              int64
# Miles               int64
# dtype: object

# %%
# Verify the dataset information
cardiofitness_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    category
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    category
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    category
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: category(3), int64(6)
# memory usage: 9.4 KB

# %% [markdown]
# ## Statistical summary of the variables

# %%
#statistical summary of the numerical variables in Cardio Fitness dataset 
cardiofitness_data.describe()
# Out:
#               Age   Education       Usage     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    28.788889   15.572222    3.455556    3.311111   53719.577778
# std      6.943498    1.617055    1.084797    0.958869   16506.684226
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44058.750000
# 50%     26.000000   16.000000    3.000000    3.000000   50596.500000
# 75%     33.000000   16.000000    4.000000    4.000000   58668.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#             Miles
# count  180.000000
# mean   103.194444
# std     51.863605
# min     21.000000
# 25%     66.000000
# 50%     94.000000
# 75%    114.750000
# max    360.000000

# %% [markdown]
# ### Observations:
#
# 1. The average age of the customers is 28.7 years while the median is 26 years and the customers ages range from 18 to 50.
# 2. The average usage is 3.4 days and median value is 3 days per week.
# 3. The mean fitness level of the customers is 3.3 and median value is 3.
# 4. The average income of the customers is 53719.58 and the median value in customers income is 50596.5
#    while the income ranges from 29562.0 to 104581.0
# 5. The average education of customers in years is 15.5 years and median value is 16 years.
# 6. The mean value for the miles expected to run is 103.19 and median value is 114.75 while the miles expected to run      range from 21 to 360.

# %%
#statistical summary of the variables in Cardio Fitness dataset 
cardiofitness_data.describe(include='all')
# Out:
#        Product         Age Gender   Education MaritalStatus       Usage  \
# count      180  180.000000    180  180.000000           180  180.000000
# unique       3         NaN      2         NaN             2         NaN
# top      TM195         NaN   Male         NaN     Partnered         NaN
# freq        80         NaN    104         NaN           107         NaN
# mean       NaN   28.788889    NaN   15.572222           NaN    3.455556
# std        NaN    6.943498    NaN    1.617055           NaN    1.084797
# min        NaN   18.000000    NaN   12.000000           NaN    2.000000
# 25%        NaN   24.000000    NaN   14.000000           NaN    3.000000
# 50%        NaN   26.000000    NaN   16.000000           NaN    3.000000
# 75%        NaN   33.000000    NaN   16.000000           NaN    4.000000
# max        NaN   50.000000    NaN   21.000000           NaN    7.000000
#
#            Fitness         Income       Miles
# count   180.000000     180.000000  180.000000
# ...

# %% [markdown]
# ### Observations:
# 1. There are a total of 180 records and no values missing in any column.
# 2. There are 3 unique products under Product category.
# 3. Top(Mode) value for Product is shown as TM195, which means TM195 product has most number of records.
#    i.e., TM195 has most sales compared to other two products.

# %% [markdown]
# ## Verify if there are any null values

# %%
cardiofitness_data.isnull().sum()
# Out:
# Product          0
# Age              0
# Gender           0
# Education        0
# MaritalStatus    0
# Usage            0
# Fitness          0
# Income           0
# Miles            0
# dtype: int64

# %% [markdown]
# Observation:There are no null values in the dataset

# %% [markdown]
# ## Verify if there are any duplicates

# %%
sum(cardiofitness_data.duplicated())
# Out:
# 0

# %% [markdown]
# Observation:There are no duplicates found.

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Univariate Analysis
#
# ###  View the distribution of the variables

# %% [markdown]
# ## Observe  Age Variable distribution

# %%
#View the distribution of the Age variable
plt.subplot(3,1,1)
sns.distplot(cardiofitness_data.Age,color="blue");
plt.axvline(cardiofitness_data["Age"].mean(),color='m',linewidth=3)# draw a line indicating mean
plt.axvline(cardiofitness_data["Age"].median(),color='b',linestyle='dashed',linewidth=2)# draw a line indicating median
plt.axvline(cardiofitness_data["Age"].mode()[0],color='w',linestyle='dashed',linewidth=1)# draw a line indicating mode
plt.subplot(3,1,2)
sns.boxplot(cardiofitness_data.Age);
plt.subplot(3,1,3)
sns.violinplot(cardiofitness_data.Age);

# %% [markdown]
# ### Observation:
# 1. The distribution of age is right skewed.
# 2. A peak can be seen in first plot around the age 25 indicating that there are more customers from the age group 25-26     years.
# 3. From the boxplot, we see that there are some outliers too.
# 4. The average age of the customers is 28.7 years and the median is 26 years.
#     Median value 26 years indicates that 50% of the customers lie below 26years.
# 5. Upper or Third quartile is at 33 years.While 75% of the customers lie below 33 years , there are also customers        above 46years until 50.

# %% [markdown]
# ## Observe Education Variable

# %%
#View the Distribution of Customers Education
plt.subplot(3,1,1)
sns.distplot(cardiofitness_data.Education);
plt.axvline(cardiofitness_data["Education"].mean(),color='m',linewidth=3)# draw a line indicating mean
plt.axvline(cardiofitness_data["Education"].median(),color='b',linestyle='dashed',linewidth=2)# draw a line indicating median
plt.axvline(cardiofitness_data["Education"].mode()[0],color='w',linestyle='dashed',linewidth=1)# draw a line indicating mode
plt.subplot(3,1,2)
sns.boxplot(cardiofitness_data.Education);
plt.subplot(3,1,3)
sns.violinplot(cardiofitness_data.Education);

# %% [markdown]
# ### Observation:
# 1. The distribution of Education is right skewed.
# 2. The median and the third quartile value for customers education is 16years.
#    There are more customers who has 16years of education as the peak indicates.
# 3. Education variable has outliers too.

# %% [markdown]
# ## Observe Income Variable

# %%
plt.subplot(3,1,1)
sns.distplot(cardiofitness_data.Usage);
plt.axvline(cardiofitness_data["Usage"].mean(),color='m',linewidth=3)# draw a line indicating mean
plt.axvline(cardiofitness_data["Usage"].median(),color='b',linestyle='dashed',linewidth=2)# draw a line indicating median
plt.axvline(cardiofitness_data["Usage"].mode()[0],color='w',linestyle='dashed',linewidth=1)# draw a line indicating mode
plt.subplot(3,1,2)
sns.boxplot(cardiofitness_data.Usage);
plt.subplot(3,1,3)
sns.violinplot(cardiofitness_data.Usage);

# %% [markdown]
# ### Observation:
# 1. The distribution of usage is right skewed.
# 2. There are some outliers for Usage variable.
# 3. The median and the lower quartile value for customers Usage of the product is around 3 days per week,which implies    that there are more customers using the treadmill around 3 days per week.

# %% [markdown]
# ## Observe Fitness Variable

# %%
plt.subplot(3,1,1)
sns.distplot(cardiofitness_data.Fitness);
plt.axvline(cardiofitness_data["Fitness"].mean(),color='m',linewidth=3)# draw a line indicating mean
plt.axvline(cardiofitness_data["Fitness"].median(),color='b',linestyle='dashed',linewidth=2)# draw a line indicating median
plt.axvline(cardiofitness_data["Fitness"].mode()[0],color='w',linestyle='dashed',linewidth=1)# draw a line indicating mode
plt.subplot(3,1,2)
sns.boxplot(cardiofitness_data.Fitness);
plt.subplot(3,1,3)
sns.violinplot(cardiofitness_data.Fitness);

# %% [markdown]
# ### Observation:
# 1. The distribution of Fitness variable is left skewed.
# 2. We see an outlier on the left side of the box plot.
# 3. The median and the lower quartile value for customers fitness score is 3 ( Score 1 being unfit and 5 being very fit).The third/upper quartile value is 4.
# 4. There are more customers whose fitness level is 3.

# %% [markdown]
# ## Observe Income Variable

# %%
plt.subplot(3,1,1)
sns.distplot(cardiofitness_data.Income);
plt.axvline(cardiofitness_data["Income"].mean(),color='m',linewidth=3)# draw a line indicating mean
plt.axvline(cardiofitness_data["Income"].median(),color='b',linestyle='dashed',linewidth=2)# draw a line indicating median
plt.axvline(cardiofitness_data["Income"].mode()[0],color='w',linestyle='dashed',linewidth=1)# draw a line indicating mode
plt.subplot(3,1,2)
sns.boxplot(cardiofitness_data.Income);
plt.subplot(3,1,3)
sns.violinplot(cardiofitness_data.Income);

# %% [markdown]
# ### Observation:
# 1. Income variable is skewed towards right.
# 2. There are more outliers with the higher income.
# 3. The median value of customers income is 50k and the spike around 50k indicates that there are more customers in        that range.

# %% [markdown]
# ##  Observe Miles variable

# %%
plt.subplot(3,1,1)
sns.distplot(cardiofitness_data.Miles);
plt.axvline(cardiofitness_data["Miles"].mean(),color='m',linewidth=3)# draw a line indicating mean
plt.axvline(cardiofitness_data["Miles"].median(),color='b',linestyle='dashed',linewidth=2)# draw a line indicating median
plt.axvline(cardiofitness_data["Miles"].mode()[0],color='w',linestyle='dashed',linewidth=1)# draw a line indicating mode
plt.subplot(3,1,2)
sns.boxplot(cardiofitness_data.Miles);
plt.subplot(3,1,3)
sns.violinplot(cardiofitness_data.Miles);

# %% [markdown]
# ### Observation:
# 1. The Miles variable is more skewed towards the right.
# 2. There are few outliers on the right side.
# 3. There is a spike around 90miles indicating that there are more customers in that range.

# %% [markdown]
# ### View the plots for categorical variables

# %%
# Function to create barplots that indicate percentage for each category.
def bar_perc(plot, feature):
    '''
    plot
    feature: 1-d categorical feature array
    '''
    total = len(feature) # length of the column
    for p in ax.patches:
        percentage = '{:.1f}%'.format(100 * p.get_height()/total) # percentage of each class of the category
        x = p.get_x() + p.get_width() / 2 - 0.05 # width of the plot
        y = p.get_y() + p.get_height()           # hieght of the plot
        ax.annotate(percentage, (x, y), size = 12) # annotate the percantage

# %% [markdown]
# ## Observe Product variable

# %%
#View the countplot on product 
plt.figure(figsize=(10,7))
ax = sns.countplot(cardiofitness_data['Product'])
bar_perc(ax,cardiofitness_data['Product'])

# %%
plt.pie(cardiofitness_data['Product'].value_counts(),labels=cardiofitness_data['Product'].unique(),radius=1,autopct='%1.1f%%')
plt.pie([1],colors=["w"],radius=0.5)
plt.show()

# %% [markdown]
# ### Observation:
# 1. 44.4% of the customers prefer TM195 model no. treadmill over TM498 and TM798 model no. treadmils.
# 2. There are more customers for TM195 product comapred to the other two products.

# %% [markdown]
# ## Observe Gender Variable

# %%
#View the Gender distribution
plt.figure(figsize=(10,7))
ax = sns.countplot(cardiofitness_data['Gender'])
bar_perc(ax,cardiofitness_data['Gender'])

# %% [markdown]
# ### Observations:
# 1. 57.8% of the customers are male.

# %% [markdown]
# ## Observe MaritalStatus

# %%
#View the MaritalStatus distribution using countplot
plt.figure(figsize=(10,7))
ax = sns.countplot(cardiofitness_data['MaritalStatus'])
bar_perc(ax,cardiofitness_data['MaritalStatus'])

# %% [markdown]
# ### Observation:
# 1. There are more partnered customers(59.4 percent) over customers who are single.

# %% [markdown]
# # Bivariate Analysis
# Plot bivariate charts between variables to understand their interaction with each other.

# %% [markdown]
# ## Corrrelation

# %%
corr=cardiofitness_data.corr()
plt.figure(figsize=(16,12))
sns.heatmap(corr, annot=True,cmap='coolwarm',
        fmt=".1f",
        xticklabels=corr.columns,
        yticklabels=corr.columns);

# %% [markdown]
# ### Observations:
# 1. We see a positive correlation between age and income which implies that people start earning more as they age.
# 2. Education is positively correlated with income , which is on expected lines.
# 3. Usage is highly correlated with Miles and Fitness.
# 4. It's an obvious correlation that as the usage increases, fitness increases and number of miles increases.

# %% [markdown]
# ## Bivariate Scatter Plots

# %%
#View the Pairplot for all the numerical columns in the dataset
sns.pairplot(cardiofitness_data, corner=True);

# %% [markdown]
# ### Observations:
#
# we get the same observation as from the correlation plot

# %% [markdown]
# ### Relationship between product and other variables in the dataset

# %% [markdown]
# ## Product vs Gender

# %%
plt.figure(figsize=(10,7))
ax=sns.countplot(cardiofitness_data["Product"],hue=cardiofitness_data["Gender"]);
bar_perc(ax,cardiofitness_data['Gender'])

# %% [markdown]
# ### Observations:
# 1. TM195 has equal number of male and female customers.
# 2. TM498 has slightly higher male customers than female customers.
# 3. TM798 has significantly higher male customers than female customers.

# %% [markdown]
# ## Product vs Marital Status

# %%
plt.figure(figsize=(10,7))
ax = sns.countplot(cardiofitness_data["Product"],hue=cardiofitness_data["MaritalStatus"]);
bar_perc(ax,cardiofitness_data['MaritalStatus'])

# %% [markdown]
# ### Observations:
# 1. It is observed that there are more partnered customers that are buying these cardio equipment.

# %% [markdown]
# ## Marital Status vs Gender

# %%
#Relationship between MaritalStatus and Gender
sns.countplot(cardiofitness_data["MaritalStatus"],hue=cardiofitness_data["Gender"]);

# %% [markdown]
# ### Observations:
#  - Partnered male and female customers purchase the products more than their single counterparts.

# %% [markdown]
# ## Product vs Age

# %%
#Relationship between product and Age
plt.figure(figsize=(10,7))
sns.boxplot(cardiofitness_data["Product"],cardiofitness_data["Age"]);

# %%
cardiofitness_data.groupby(["Product"])['Age'].median()
# Out:
# Product
# TM195    26
# TM498    26
# TM798    27
# Name: Age, dtype: int64

# %%
cardiofitness_data.groupby(["Product"])['Age'].mean()
# Out:
# Product
# TM195    28.55
# TM498    28.90
# TM798    29.10
# Name: Age, dtype: float64

# %% [markdown]
# ### Observations:
# 1. There is not a significant difference in the mean or median values of ages of the customers.
# 2. There are outliers for all the products but a few extra outliers for TM798 model.
# 3. The TM798 product has customers mostly in the ages ranging from 22-38 while the other two products have customers mostly in the ages ranging from 18-48.This shows that TM798 have more customers in a shorter age range.

# %% [markdown]
# ## Product vs Income

# %%
#Relationship between product and Income
sns.boxplot(cardiofitness_data["Product"],cardiofitness_data["Income"]);

# %%
sns.violinplot(cardiofitness_data["Product"],cardiofitness_data["Income"]);

# %%
sns.pointplot(cardiofitness_data["Product"],cardiofitness_data["Income"]);

# %% [markdown]
# ### Observations:
# 1. There is not much difference in the income range of the customers using TM195 and TM498 models but the customers who use TM798 model have significantly higher incomes.
# 2. There is not much skewness observed in the plots.
# 3. The median income value of TM798 customers is significantly higher than the median value of other two products .
# 4. The higher income points to product TM798 being more expensive.
# 5. The average income of customers who use TM498 is slightly higher than the customers who use TM195.
#
# Lets explore the other features of the products that are attracting customers and also the customer characteristics of individual products.

# %% [markdown]
# ## Product vs Education

# %%
#Relationship between product and Education
sns.boxplot(cardiofitness_data["Product"],cardiofitness_data["Education"]);

# %% [markdown]
# ### Observation:
# 1. The education variable for  TM798 customers range from 14-21 years while the TM195 and TM498 customers education range from 12-18years.
# 2. Again no difference in TM195 and TM498 customers education but customers of TM798 model seems to have higher education.

# %%
#Relationship between Education and Income
sns.lmplot(x="Education",y="Income",data=cardiofitness_data);

# %% [markdown]
# ### Observation:
# 1. This plot clearly indicates the positive correlation between education and income.

# %%
#Relationship between Age and Income
sns.lmplot(x="Age",y="Income",data=cardiofitness_data);

# %% [markdown]
# ### Observation:
# 1. The obvious positive correlation between Age and income.

# %% [markdown]
# ## Product vs Fitness

# %%
#Relationship between product and Fitness
sns.barplot(cardiofitness_data["Product"],cardiofitness_data["Fitness"]);

# %%
sns.boxplot(cardiofitness_data["Product"],cardiofitness_data["Fitness"]);

# %%
cardiofitness_data.groupby(["Product"])['Fitness'].mean()
# Out:
# Product
# TM195    2.9625
# TM498    2.9000
# TM798    4.6250
# Name: Fitness, dtype: float64

# %% [markdown]
# ### Observations:
# 1. The customers using TM195 and TM498 seem to have comparable fitness levels.
# 2. Customers using TM798 model have higher fitness levels compared to the customers using other two products.
# 3. This indicates that customers who have higher fitness levels are choosing TM798 model.

# %% [markdown]
# ## Product vs Usage

# %%
#Relationship between product and Usage
sns.pointplot(cardiofitness_data["Product"],cardiofitness_data["Usage"]);

# %%
#Relationship between product and Usage
sns.boxplot(x="Product",y="Usage",data=cardiofitness_data);

# %% [markdown]
# ### Observation:
# 1. The expected average usage of the TM195 and TM498 model treadmills per week by the customers seems to be comparable.
# 2. But the expected average usage of TM798 treadmill per week is higher than TM195 and TM498 model treadmills.
# 3. The outliers for TM798 indicates that are customers for TM798 who wish to use the treadmill all 7 days a week.
# 4. This implies that customers who wish to use the treadmill more on weekly basis prefer to buy TM798. This also indicates that product is more durable.

# %% [markdown]
# ## Product vs Miles

# %%
#Relationship between product and Miles 
sns.boxplot(cardiofitness_data["Product"],cardiofitness_data["Miles"]);

# %%
cardiofitness_data.groupby(["Product"])['Miles'].mean()
# Out:
# Product
# TM195     82.787500
# TM498     87.933333
# TM798    166.900000
# Name: Miles, dtype: float64

# %% [markdown]
# ### Observations:
# 1. The TM798 customers expects to run anywhere from 80-360 miles per week and
#    TM195 customers expects to run in the range 38-188 miles per week
#    and TM798 customers expects to run in the range 21-212 miles.
# 2. As we can see,there is notable difference in the average miles expected to run by the customers from TM195 to TM498    model treadmills while the median value seems to be same..
# 3. There is a significant increase in the average expected Miles to be run per week for TM798 model compared to other two products
# 4. This supports our previous observation that TM798 model treadmill is more durable.

# %% [markdown]
# ### So far ,we observed that TM798 model is more expensive and is purchased by  high income (avg 75k)  male and female customers. These customers also have higher fitness levels wish to use the treadmill more per week. Based on the customer profiles (high income and higher usage), we can conjecture that the product has more features and is more durable than the other two products.

# %% [markdown]
# ### The characteristics of customers using TM195 and TM498 are not that distinguishable,except income and Miles. Both these parameters are slightly higher for TM498 compared to TM195.

# %% [markdown]
# # Multivariate analysis

# %%
#To findout the total number of customers for each product based on Gender and MaritalStatus
cardiofitness_data.groupby(by = ['Product','Gender'])['MaritalStatus'].value_counts()
# Out:
# Product  Gender  MaritalStatus
# TM195    Female  Partnered        27
#                  Single           13
#          Male    Partnered        21
#                  Single           19
# TM498    Female  Partnered        15
#                  Single           14
#          Male    Partnered        21
#                  Single           10
# TM798    Female  Partnered         4
#                  Single            3
#          Male    Partnered        19
#                  Single           14
# Name: MaritalStatus, dtype: int64

# %%
#To findout the percentage of customers for each product based on Gender and MaritalStatus
percentage=(cardiofitness_data.groupby(by = ['Product','Gender'])['MaritalStatus'].value_counts())
total=cardiofitness_data.groupby(by=['Gender','MaritalStatus'])['Product'].count()
percent=100 * percentage/total
percent
# Out:
# Gender  MaritalStatus  Product
# Female  Partnered      TM195      58.695652
#                        TM498      32.608696
#                        TM798       8.695652
#         Single         TM195      43.333333
#                        TM498      46.666667
#                        TM798      10.000000
# Male    Partnered      TM195      34.426230
#                        TM498      34.426230
#                        TM798      31.147541
#         Single         TM195      44.186047
#                        TM498      23.255814
#                        TM798      32.558140
# dtype: float64

# %% [markdown]
# ### Observations:
# 1.It is observed that 58.6 percent of the partnered females are choosing TM195,which is very significant.

# %%
cardiofitness_data.groupby(by = ['Product','Gender','MaritalStatus']).mean()
# Out:
#                                     Age  Education     Usage   Fitness  \
# Product Gender MaritalStatus
# TM195   Female Partnered      28.333333  14.888889  2.851852  2.851852
#                Single         28.692308  15.538462  3.000000  2.923077
#         Male   Partnered      31.380952  15.428571  3.285714  2.857143
#                Single         25.631579  14.473684  3.263158  3.263158
# TM498   Female Partnered      30.000000  15.200000  3.333333  2.933333
#                Single         28.142857  15.214286  2.928571  2.785714
#         Male   Partnered      30.380952  15.285714  2.857143  2.904762
#                Single         25.200000  14.500000  3.300000  3.000000
# TM798   Female Partnered      29.000000  17.500000  5.250000  5.000000
#                Single         24.333333  18.333333  4.666667  4.000000
#         Male   Partnered      30.000000  17.421053  4.842105  4.631579
#                Single         28.928571  16.928571  4.571429  4.642857
#
# ...

# %% [markdown]
# ### Observations:
# - The average fitness of TM195 customers is slightly higher than the TM498 customers .
# - And average income of TM195 customers is lower than the average income of TM498 customers.

# %%
sns.catplot(x="Gender",hue="MaritalStatus",data=cardiofitness_data,kind="count",col="Product");

# %% [markdown]
# ### Observation:
# 1. We observe that there are more female partnered customers for TM195 treadmill.
# 2. The majority of TM498 treadmill customers are partnered male.
# 3. Among the single customers, most men prefer TM195 over TM498.

# %% [markdown]
# Let us explore more to findout the characteristics of the customers who are Partnered.

# %% [markdown]
# ## Extract Partnered data and load it

# %%
Cardio_Partnered=cardiofitness_data[cardiofitness_data["MaritalStatus"]=="Partnered"]

# %% [markdown]
# ### Product vs Usage vs Gender

# %%
sns.lineplot(x="Product",y="Usage",data=Cardio_Partnered,hue="Gender");

# %% [markdown]
# ### Observations:
# The average usage of TM195 product by partnered females and the average usage of TM498 customers by partnered males is less comapred to others.

# %% [markdown]
# ### Product vs Income vs Gender

# %%
sns.lineplot(x="Product",y="Income",data=Cardio_Partnered,hue="Gender");

# %% [markdown]
# ### Observations:
# - The average income of Partnered females who use TM195 product is lesser than the others.
# - The average income of both partnered male and females who use TM498 is almost the same.
# - The average income of both partnered male and females who use TM798 is higher compared to other product customers

# %% [markdown]
# ### Product vs Miles vs Gender

# %%
sns.lineplot(x="Product",y="Miles",data=Cardio_Partnered,hue="Gender");

# %% [markdown]
# ### Observations:
# - The average miles expected to run by TM498 partnered customers is higher than the TM195 partnered customers but lower than TM798.
# - Overall, the average miles expected to run by TM798 partnered customers is significantly higher.

# %%
### Product vs Fitness vs Gender

# %%
sns.lineplot(x="Product",y="Fitness",data=Cardio_Partnered,hue="Gender");

# %% [markdown]
# ### Observations:
# There is not an observable difference in the fitness of partnered customers of TM195 and TM498.

# %% [markdown]
# ## We observe that the average income,fitness and miles expected to run by TM195 partnered customers are lower than other product customers.The average usage of TM195 is comparable to TM498 partnered male customers, and the lowest among all customers.

# %% [markdown]
# ## Extract Single customers data

# %%
Cardio_Single=cardiofitness_data[cardiofitness_data["MaritalStatus"]=="Single"]

# %%
#Product vs usage of Single customers
sns.lineplot(x="Product",y="Usage",data=Cardio_Single,hue="Gender");

# %% [markdown]
# ### Observations:
# The average usage by TM498 Single females is the lowest.

# %%
#Product vs Fitness of Single customers
sns.lineplot(x="Product",y="Fitness",data=Cardio_Single,hue="Gender");

# %% [markdown]
# ### Observations:
# - The fitness levels of TM498 Single customers is the lowest among all the other products customers who are single.

# %%
sns.lineplot(x="Product",y="Miles",data=Cardio_Single,hue="Gender");

# %% [markdown]
# ### Observations:
# The average miles expected to run by single Males of TM195 is higher than TM498 customers

# %%
sns.lineplot(x="Product",y="Income",data=Cardio_Single,hue="Gender");

# %% [markdown]
# ### Observations:
# The income of TM195 product single customers is lower than the other product single customers.

# %% [markdown]
# ## We Observe that the average usage,miles and fitness of TM498 single customers is lower than other product customers. The income of TM498 single customers is slightly higher than TM195 but lower than TM798.
#
# ## Separating the partnered and single customers provided us some insight into the customer characteristics of TM195 and TM498 customers.

# %% [markdown]
# ## Let us explore TM195 and TM498 further to more details about the customers
# ## Extract TM195 data and load it

# %%
#Extract TM195 data and load it into a variable
cardio_TM195=cardiofitness_data[cardiofitness_data["Product"]=="TM195"]
cardio_TM195.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47

# %%
cardio_TM195.shape #view the shape of the dataset
# Out:
# (80, 9)

# %%
cardio_TM195.describe()# View the five point summary
# Out:
#              Age  Education      Usage   Fitness       Income       Miles
# count  80.000000  80.000000  80.000000  80.00000     80.00000   80.000000
# mean   28.550000  15.037500   3.087500   2.96250  46418.02500   82.787500
# std     7.221452   1.216383   0.782624   0.66454   9075.78319   28.874102
# min    18.000000  12.000000   2.000000   1.00000  29562.00000   38.000000
# 25%    23.000000  14.000000   3.000000   3.00000  38658.00000   66.000000
# 50%    26.000000  16.000000   3.000000   3.00000  46617.00000   85.000000
# 75%    33.000000  16.000000   4.000000   3.00000  53439.00000   94.000000
# max    50.000000  18.000000   5.000000   5.00000  68220.00000  188.000000

# %% [markdown]
# ### Observation:
# The average age of TM195 customers is 28.5 years and the median is 26years.
# The average education of TM195 customers is 15 years and the median is 16years.
# The average value of usage and the median value of usage is same.Similarly with fitness.
# The mean income of TM195 customers is 46418.

# %% [markdown]
# ## HeatMap to observe correlation between numerical variables for TM195

# %%
plt.figure(figsize=(10,5))
sns.heatmap(cardio_TM195.corr(), annot=True,cmap='coolwarm',fmt=".1f");

# %% [markdown]
# ### Observation:
# 1. We notice that age is strongly correlated with income and negatively correlated with usage and miles.
# 2. As obvious, education is positively correlated with Age and Income.
# 3. Usage is highly correlated with Miles and Fitness and negatively correlated with Age,Income.
# 4. Fitness is strongly correlated with Miles and also highly correlated with Usage.
# 5. Income is negatively correlated with Usage and Miles.

# %% [markdown]
# ## Extract TM498 data

# %%
#Extract TM498 data into a variable
cardio_TM498=cardiofitness_data[cardiofitness_data["Product"]=="TM498"]
cardio_TM498.head()
# Out:
#    Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 80   TM498   19    Male         14        Single      3        3   31836
# 81   TM498   20    Male         14        Single      2        3   32973
# 82   TM498   20  Female         14     Partnered      3        3   34110
# 83   TM498   20    Male         14        Single      3        3   38658
# 84   TM498   21  Female         14     Partnered      5        4   34110
#
#     Miles
# 80     64
# 81     53
# 82    106
# 83     95
# 84    212

# %%
cardio_TM498.shape # View the shape of the dataset
# Out:
# (60, 9)

# %%
cardio_TM498.describe() # View the five point summary
# Out:
#              Age  Education      Usage   Fitness        Income       Miles
# count  60.000000  60.000000  60.000000  60.00000     60.000000   60.000000
# mean   28.900000  15.116667   3.066667   2.90000  48973.650000   87.933333
# std     6.645248   1.222552   0.799717   0.62977   8653.989388   33.263135
# min    19.000000  12.000000   2.000000   1.00000  31836.000000   21.000000
# 25%    24.000000  14.000000   3.000000   3.00000  44911.500000   64.000000
# 50%    26.000000  16.000000   3.000000   3.00000  49459.500000   85.000000
# 75%    33.250000  16.000000   3.250000   3.00000  53439.000000  106.000000
# max    48.000000  18.000000   5.000000   4.00000  67083.000000  212.000000

# %% [markdown]
# ## HeatMap to observe correlation between numerical variables for TM195

# %%
plt.figure(figsize=(10,5))
sns.heatmap(cardio_TM498.corr(), annot=True,cmap='coolwarm',fmt=".1f");

# %% [markdown]
# ### Observation:
# 1. We see that age variable is strongly correlated with Income and negatively correlated with Usage,Fitness,and Miles.
# 2. Education is positively correlated with Age and Income and negatively correlated with Usage,Fitness,Miles.
# 3. Income is negatively correlated with Fitness and Miles and positively correlated with Usage.
# 4. Usage is highly correlated with Miles and negatively correlated with Age,Education and Income.
# 5. Fitness is highly correlated with Miles,Miles per usage and negatively correlated with Age,Education and Income.
# 6. Miles is negatively correlated with Age,Education and Income.

# %% [markdown]
# ### Verify TM195 vs TM498 distribution plots.
#
# ### Age Distribution

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
sns.histplot(cardio_TM195["Age"]);
plt.xlabel("TM195-Age")
plt.subplot(1,2,2)
sns.histplot(cardio_TM498["Age"]);
plt.xlabel("TM498-Age")
plt.show()

# %% [markdown]
# ### Observations frm TM195 age distribution:
# 1. The range of customers age for TM195 is 18-50 years.
# 2. The median age of TM195 customers is 26 years.
# 3. There is one outlier at the age 50.
# 4. There is a hump from 23-26 indicating that there are more customers for TM195 from ages 23-26years.
#
# ### Observations frm TM498 age distribution:
# 1. The range of customers age for TM498 is 18-48 years.
# 2. The median age of TM498 customers is 26 years.
# 3. There is one outlier at the age 48.
# 4. There is a hump from 23-28 indicating that there are more customers for TM498 from ages 23-28years.
#
# There is not much insights from age distribution.

# %% [markdown]
# ### Miles distribution

# %%
#compare Miles distribution plots of TM195 and TM498
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
sns.histplot(cardio_TM195["Miles"]);
plt.xlabel("TM195-Miles")
plt.subplot(1,2,2)
sns.histplot(cardio_TM498["Miles"]);
plt.xlabel("TM498-Miles")
plt.show()

# %% [markdown]
# ### Observation:
# - For TM195, we see a peak at 60-75 miles while the peak is at 80-110 for TM498. This clearly indicates that TM498 customers expects to put more miles on the treadmill.
# - The average number of miles run by TM498 customers is slightly higher than TM195.

# %% [markdown]
# ## Age vs Usage plots of TM195 and TM498

# %%
#compare Age vs Usage plots of TM195 and TM498
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
sns.lineplot(x="Age",y="Usage",data=cardio_TM195,palette="Set1");
plt.xlabel("TM195-Age")
plt.ylabel("TM195-Usage")
plt.subplot(1,2,2)
sns.lineplot(x="Age",y="Usage",data=cardio_TM498,palette="Set1");
plt.xlabel("TM498-Age")
plt.ylabel("TM498-Usage")
plt.show()

# %% [markdown]
# ### Observations:
# - We observe increasing trend in the usage with age in TM195 customers wheras in TM498 customers,decreasing trend in usage is noticed.
# - As we know, the majority of the customers of TM195 fall in 23-26 years and from the above plot, we see that the usage is around 3-3.5.
# - The majority of the TM498 customers age fall in 23-28 years and from the above plot, we notice that their usage levels are around 4 for majority, which is higher than TM195.

# %% [markdown]
# ## Age vs Fitness plots of TM195 and TM498

# %%
#compare Age vs Fitness plots of TM195 and TM498
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
sns.lineplot(x="Age",y="Fitness",data=cardio_TM195,palette="Set1");
plt.xlabel("TM195-Age")
plt.ylabel("TM195-Fitness")
plt.subplot(1,2,2)
sns.lineplot(x="Age",y="Fitness",data=cardio_TM498,palette="Set1");
plt.xlabel("TM498-Age")
plt.ylabel("TM498-Fitness")
plt.show()

# %% [markdown]
# ## Age vs Miles plots of TM195 and TM498

# %%
#compare Age vs Miles plots of TM195 and TM498
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
sns.lineplot(x="Age",y="Miles",data=cardio_TM195,palette="Set1");
plt.xlabel("TM195-Age")
plt.ylabel("TM195-Miles")
plt.subplot(1,2,2)
sns.lineplot(x="Age",y="Miles",data=cardio_TM498,palette="Set1");
plt.xlabel("TM498-Age")
plt.ylabel("TM498-Miles")
plt.show()

# %% [markdown]
# ### Observations:
# There are customers who wish to put miles more than 120 for TM195 and it is below 100 for TM498.

# %% [markdown]
# ## Age vs Fitness plots of TM195 and TM498

# %%
#compare Age vs Fitness plots of TM195 and TM498
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
sns.lineplot(x="Age",y="Fitness",data=cardio_TM195,palette="Set1");
plt.xlabel("TM195-Age")
plt.ylabel("TM195-Fitness")
plt.subplot(1,2,2)
sns.lineplot(x="Age",y="Fitness",data=cardio_TM498,palette="Set1");
plt.xlabel("TM498-Age")
plt.ylabel("TM498-Fitness")
plt.show()

# %% [markdown]
# ### Observations:
# The fitness levels of TM195 customers is higher than TM498 customers.

# %% [markdown]
# ## Comparision between TM195 and TM498
# We noticed that TM498 customers have more average income than TM195 customers,indicating TM498 being expensive.
# It is also observed that average miles that were expected to run on TM498(87.9 miles) is slightly higher than TM195(82.7 miles).
#
# On the other hand, there are more single male customers that expect to run more miles on TM195(99 miles) than TM498 indicating that both the threadmills are equally durable.
#
# Inference:
#
# Higher incomes of TM498 customers than TM195 (both earning less than sample size average income) indicates that it is slightly more expensive than TM195, maybe due to additional features. However, they are both equally durable.

# %% [markdown]
# # Conclusion and Recommendations

# %% [markdown]
# ## Conclusion
# We analyzed a dataset containing 180 records of customers of treadmill products of a retail store
# called Cardio Good Fitness information. The dataset includes information on three treadmill products
# and their customer details like gender, marital status, income, fitness, usage, and expected miles to
# run. The main feature of interest is analyzing customers&#39; profiles for each product and proposing
# recommendations to the store to help them target new customers. To accomplish this, univariate,
# bivariate, and multivariate analyses were performed comparing the products based on various
# customer characteristics. The following are the results.
# - The sales for TM195 were the highest among the three products.
# - 57.8 percent of the customers are male and 59.4 percent of the customers are partnered.
# - The number of male and female customers for TM195 model is same; there are a few more male customers than female for TM498; the number of male customers are significantly higher than female customers for TM798.
# - Majority of the customers fall in a smaller age range (22-38) for TM798 model compared to the other two products.
# - The customers who use the TM798 model have significantly higher incomes than the customers who use the other two products. The income points to the product TM798 being more expensive.
# - The customers of TM798 model seems to have higher education while the education of TM195 and TM498 customers seems to be same.
# - The customers using TM195 and TM498 seem to have comparable fitness levels while the customers using TM798 model have higher fitness levels. This indicates that customers who have higher fitness levels are choosing TM798 model.
# - The expected average usage of the TM195 and TM498 model treadmills per week by the customers seems to be comparable while it is higher for TM798 model. This implies that customers who wish to use the treadmill more on weekly basis prefer to buy TM798, which points us to the product being more durable.
# - The average miles per usage for TM195 is slightly lower than TM498 model treadmill. The average miles per usage for TM798 model is significantly higher than other two products.
# - It is observed that 58.6 percent of the partnered females choose TM 195, which is very significant.
# - It is observed that TM498 customers have more average income than TM195 customers indicating that it is slightly more expensive than TM195, maybe due to additional features. However, customer perception about their durability seems to be the same (based on the miles the average customers are expected to run)
#
# ### Customers Profile:
# ### TM798 customer characteristics
# - There were clear differences in the income, fitness, and usage patterns of the customers who purchased TM798 compared to the customers who purchased the other two products.
# - They earn higher income (average of 75,000) and have higher education.
# - They have higher fitness level and higher usage expectations, and intend to run more miles per week.
# - There are significantly more male customers (82.5 percent) than female customers (17.5 percent) for TM798 model.
# - The typical customer for TM 798 is a male runner with a median age of 27 years earning significantly higher than average income (75,000 vs population average of 53,720), and intends to use the thread mill regularly (average of 4 days a week).
#
# The characteristics of people who purchased TM195 and TM498 were so close, they were almost indistinguishable.  The following are some observations.
#
# ### TM195 Customer characteristics
# - The sales for TM195 were the highest among the three products.
# - Majority of the partnered females (58.7 percent) prefer TM195 to other two products.
# - Majority of the single male customers (44.18 percent) prefer TM 195.
# - The peak age range for customers is 23 – 26 years with a median age of 26
#
# The typical customer for TM195 is either a single male or a partnered female between the ages 23-26, has average fitness, and earns a lower than average income (46,418 vs the population average of 53,720)
#
# ### TM498 customer characteristics
# - The average income of TM498 customers is slightly higher than the TM195 customers' average income but still lower (48,974) than the population average (53,720)
# - The average miles the customers expect to run are higher for TM498 customers than TM195.
# - The peak age range for customers is 23-28 years for TM498 model with a median age of 26.
#
# The typical customer for TM498 is a partnered male or a female between the ages 23 - 26, earns a lower than average income (48,974 vs the population average of 53,720), and has lower than average fitness.

# %% [markdown]
# ## Recommendations to business
# 1.	Cardio Good Fitness sells more TM195 treadmills indicating more demand for TM195 over the other two treadmills. The store should stock more TM195 treadmills to satisfy the demand.
# 2.	It is observed that both male and female customers with higher education, higher income are buying TM798 model. So, CardioGoodFitness should survey the area for the demographics with higher education and higher income, and market the product more in those locations. In addition to the regular advertising streams (like social media, Tv ads, newspapers, magazines), the retail store can also partner with organizations, gyms, and shopping malls to extend their reach to the potential customers. They should also ensure the availability of the TM798 product stock in those locations.
# 3.	TM798 model treadmill is also obtained by customers whose fitness levels are high and/or who wish to use the treadmill more. Therefore, CardioGoodFitness should clearly advertise the benefits of the product features (increasing resistance, longevity) the customer will enjoy after purchasing the product. The store can organize marathon races to market their product and attract new customers (runners).
# 4. The lesser sales of TM798 could be because of the availability of gym services in the areas where high income people live.
# 5.	It is observed that majority of the female partnered customers are choosing TM195 treadmill. So, CardioGoodFitness should design strategies - providing excellent customer service, rebates, and designing studios to make them more conducive to shopping with children -  to attract female partnered customers to buy TM195 product.
# 6.	As most of the customers are educated and as most of the people are buying the products based on the reviews, we need to collect information on the product reviews and provide solutions to the customers based on the reviews.
# 7.	A survey should be conducted on the existing customers to find out more details and the advertising campaigns should be designed based on the survey.
# 8.	It may also be a good idea for the store to request the customers who purchase TM 195 and TM 498 to fill a questionnaire to better understand them, and advertise the products accordingly.

# %% [markdown]
# ## Furthur Analysis
# Dig deeper to explore why partnered females prefer TM195 over TM498.
# We also need to analyse why there are not much sales for TM498 compared to TM195 treadmill, when there is not much distinguishing characteristics between their customers. Conducting a survey of customers to understand their choice selection will be very useful.

# %% [markdown]
# ## Data profiling using Pandas Profiling to look at the EDA

# %%
from pandas_profiling import ProfileReport

profile = ProfileReport(cardiofitness_data)
# to view report created by pandas profile
profile
# Out:
# ...
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v2.9.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2020-12-12 02:36:36.337372&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
# to save report obtained via pandas profiling
profile.to_file('/Users/srujana/Downloads/output.html')
